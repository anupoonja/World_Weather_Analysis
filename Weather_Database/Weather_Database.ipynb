# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the dependencies
import requests
# Import the API keys
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginnng Data Retrieval    ")
print("---------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set number and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description" : city_description})
        
    # If an error is exerienced, skip the city.
    except:
        print(f"City '{city}' not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginnng Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | saryshagan
# City 'saryshagan' not found. Skipping...
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | dedza
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | pafos
# Processing Record 7 of Set 1 | novyy urengoy
# Processing Record 8 of Set 1 | taolanaro
# City 'taolanaro' not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | olafsvik
# Processing Record 11 of Set 1 | beisfjord
# Processing Record 12 of Set 1 | cidreira
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | de aar
# Processing Record 15 of Set 1 | coihaique
# Processing Record 16 of Set 1 | gandu
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | mys shmidta
# City 'mys shmidta' not found. Skipping...
# Processing Record 19 of Set 1 | santiago tuxtla
# Processing Record 20 of Set 1 | barentsburg
# City 'barentsburg' not found. Skipping...
# Processing Record 21 of Set 1 | corinto
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | phan thiet
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | saint-philippe
# Processing Record 26 of Set 1 | pucallpa
# Processing Record 27 of Set 1 | makat
# Processing Record 28 of Set 1 | vetovo
# Processing Record 29 of Set 1 | harda
# Processing Record 30 of Set 1 | nicoya
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | rundu
# Processing Record 33 of Set 1 | mantua
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | matara
# Processing Record 36 of Set 1 | lazo
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | assela
# City 'assela' not found. Skipping...
# Processing Record 39 of Set 1 | lebu
# Processing Record 40 of Set 1 | hermiston
# Processing Record 41 of Set 1 | namibe
# Processing Record 42 of Set 1 | teahupoo
# Processing Record 43 of Set 1 | nemuro
# Processing Record 44 of Set 1 | illoqqortoormiut
# City 'illoqqortoormiut' not found. Skipping...
# Processing Record 45 of Set 1 | scarborough
# Processing Record 46 of Set 1 | artyk
# City 'artyk' not found. Skipping...
# Processing Record 47 of Set 1 | belushya guba
# City 'belushya guba' not found. Skipping...
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | san ramon
# Processing Record 2 of Set 2 | mogadouro
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | liyang
# Processing Record 5 of Set 2 | ancud
# Processing Record 6 of Set 2 | hovd
# Processing Record 7 of Set 2 | puerto cabello
# Processing Record 8 of Set 2 | basqal
# Processing Record 9 of Set 2 | atherton
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | gonaives
# Processing Record 13 of Set 2 | raduzhnyy
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | bethel
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | matagami
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | ilhabela
# Processing Record 22 of Set 2 | biloela
# Processing Record 23 of Set 2 | imbituba
# Processing Record 24 of Set 2 | kungurtug
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | komarikhinskiy
# Processing Record 27 of Set 2 | saldanha
# Processing Record 28 of Set 2 | zolotinka
# City 'zolotinka' not found. Skipping...
# Processing Record 29 of Set 2 | ransang
# Processing Record 30 of Set 2 | birjand
# Processing Record 31 of Set 2 | pangoa
# Processing Record 32 of Set 2 | kiama
# Processing Record 33 of Set 2 | clyde river
# Processing Record 34 of Set 2 | tucano
# Processing Record 35 of Set 2 | senneterre
# Processing Record 36 of Set 2 | arraial do cabo
# Processing Record 37 of Set 2 | netishyn
# Processing Record 38 of Set 2 | lindi
# Processing Record 39 of Set 2 | sitka
# Processing Record 40 of Set 2 | faanui
# Processing Record 41 of Set 2 | prachuap khiri khan
# Processing Record 42 of Set 2 | treinta y tres
# Processing Record 43 of Set 2 | kruisfontein
# Processing Record 44 of Set 2 | san vicente
# Processing Record 45 of Set 2 | zhigansk
# Processing Record 46 of Set 2 | longlac
# City 'longlac' not found. Skipping...
# Processing Record 47 of Set 2 | schotten
# Processing Record 48 of Set 2 | homer
# Processing Record 49 of Set 2 | ardersier
# City 'ardersier' not found. Skipping...
# Processing Record 50 of Set 2 | vila velha
# Processing Record 1 of Set 3 | tsihombe
# City 'tsihombe' not found. Skipping...
# Processing Record 2 of Set 3 | ulladulla
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | lazaro cardenas
# Processing Record 5 of Set 3 | codrington
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | concarneau
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | quatre cocos
# Processing Record 14 of Set 3 | moose factory
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | verkhnyaya inta
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | ruteng
# Processing Record 19 of Set 3 | nizhneyansk
# City 'nizhneyansk' not found. Skipping...
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | katobu
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | ostrovnoy
# Processing Record 24 of Set 3 | port moresby
# Processing Record 25 of Set 3 | north bend
# Processing Record 26 of Set 3 | ponta do sol
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | labytnangi
# Processing Record 29 of Set 3 | bengkulu
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | chagda
# City 'chagda' not found. Skipping...
# Processing Record 32 of Set 3 | grootfontein
# Processing Record 33 of Set 3 | hervey bay
# Processing Record 34 of Set 3 | necochea
# Processing Record 35 of Set 3 | taoudenni
# Processing Record 36 of Set 3 | khormuj
# City 'khormuj' not found. Skipping...
# Processing Record 37 of Set 3 | husavik
# Processing Record 38 of Set 3 | ati
# Processing Record 39 of Set 3 | carnarvon
# Processing Record 40 of Set 3 | mega
# Processing Record 41 of Set 3 | tiznit
# Processing Record 42 of Set 3 | gua musang
# Processing Record 43 of Set 3 | grand river south east
# City 'grand river south east' not found. Skipping...
# Processing Record 44 of Set 3 | karratha
# Processing Record 45 of Set 3 | tiarei
# Processing Record 46 of Set 3 | opuwo
# Processing Record 47 of Set 3 | delta del tigre
# Processing Record 48 of Set 3 | castro
# Processing Record 49 of Set 3 | okha
# Processing Record 50 of Set 3 | itoman
# Processing Record 1 of Set 4 | kamenskoye
# City 'kamenskoye' not found. Skipping...
# Processing Record 2 of Set 4 | zhuhai
# Processing Record 3 of Set 4 | tanout
# Processing Record 4 of Set 4 | talcahuano
# Processing Record 5 of Set 4 | lake havasu city
# Processing Record 6 of Set 4 | cabo san lucas
# Processing Record 7 of Set 4 | bubaque
# Processing Record 8 of Set 4 | camacupa
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | kemijarvi
# Processing Record 11 of Set 4 | waipawa
# Processing Record 12 of Set 4 | talavera de la reina
# Processing Record 13 of Set 4 | arkhangelos
# City 'arkhangelos' not found. Skipping...
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | pauini
# Processing Record 16 of Set 4 | barrow
# Processing Record 17 of Set 4 | pahrump
# Processing Record 18 of Set 4 | mudgee
# Processing Record 19 of Set 4 | brewster
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | sironj
# Processing Record 22 of Set 4 | berlevag
# Processing Record 23 of Set 4 | faya
# Processing Record 24 of Set 4 | montespertoli
# Processing Record 25 of Set 4 | bambous virieux
# Processing Record 26 of Set 4 | sawakin
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | governador valadares
# Processing Record 29 of Set 4 | vage
# Processing Record 30 of Set 4 | praia da vitoria
# Processing Record 31 of Set 4 | petrovsk-zabaykalskiy
# Processing Record 32 of Set 4 | nara
# Processing Record 33 of Set 4 | bredasdorp
# Processing Record 34 of Set 4 | saleaula
# City 'saleaula' not found. Skipping...
# Processing Record 35 of Set 4 | bluff
# Processing Record 36 of Set 4 | fare
# Processing Record 37 of Set 4 | morehead
# Processing Record 38 of Set 4 | san ciro de acosta
# Processing Record 39 of Set 4 | cape town
# Processing Record 40 of Set 4 | sola
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | kandalaksha
# Processing Record 43 of Set 4 | alta floresta
# Processing Record 44 of Set 4 | christchurch
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | vaitupu
# City 'vaitupu' not found. Skipping...
# Processing Record 47 of Set 4 | dali
# Processing Record 48 of Set 4 | pangkalanbuun
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | lavrentiya
# Processing Record 1 of Set 5 | muli
# Processing Record 2 of Set 5 | atyrau
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | el sauzal
# Processing Record 5 of Set 5 | whyalla
# Processing Record 6 of Set 5 | petukhovo
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | edelira
# Processing Record 9 of Set 5 | tasiilaq
# Processing Record 10 of Set 5 | cedral
# Processing Record 11 of Set 5 | tumannyy
# City 'tumannyy' not found. Skipping...
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | tabiauea
# City 'tabiauea' not found. Skipping...
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | vaitape
# Processing Record 16 of Set 5 | padang
# Processing Record 17 of Set 5 | tateyama
# Processing Record 18 of Set 5 | nathdwara
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | uyuni
# Processing Record 21 of Set 5 | bandarbeyla
# Processing Record 22 of Set 5 | saint anthony
# Processing Record 23 of Set 5 | cayenne
# Processing Record 24 of Set 5 | tasbuget
# City 'tasbuget' not found. Skipping...
# Processing Record 25 of Set 5 | challapata
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | bosaso
# Processing Record 28 of Set 5 | qaanaaq
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | kon tum
# Processing Record 31 of Set 5 | ahumada
# City 'ahumada' not found. Skipping...
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | lawrenceburg
# Processing Record 34 of Set 5 | ixtapa
# Processing Record 35 of Set 5 | sistranda
# Processing Record 36 of Set 5 | kysyl-syr
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | apc
# Processing Record 39 of Set 5 | severo-kurilsk
# Processing Record 40 of Set 5 | esperance
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | teguldet
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | boundiali
# Processing Record 47 of Set 5 | saurimo
# Processing Record 48 of Set 5 | vostok
# Processing Record 49 of Set 5 | nipawin
# Processing Record 50 of Set 5 | amderma
# City 'amderma' not found. Skipping...
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | ambilobe
# Processing Record 3 of Set 6 | abaza
# Processing Record 4 of Set 6 | huilong
# Processing Record 5 of Set 6 | grand gaube
# Processing Record 6 of Set 6 | port hardy
# Processing Record 7 of Set 6 | sayat
# Processing Record 8 of Set 6 | saint-prosper
# Processing Record 9 of Set 6 | laje
# Processing Record 10 of Set 6 | fenoarivo
# Processing Record 11 of Set 6 | kinablangan
# Processing Record 12 of Set 6 | guadalupe
# Processing Record 13 of Set 6 | timra
# Processing Record 14 of Set 6 | carquefou
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | marsabit
# Processing Record 17 of Set 6 | abu samrah
# Processing Record 18 of Set 6 | kutum
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | okhotsk
# Processing Record 21 of Set 6 | dunedin
# Processing Record 22 of Set 6 | ous
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | glendive
# Processing Record 25 of Set 6 | golfito
# Processing Record 26 of Set 6 | aqtobe
# Processing Record 27 of Set 6 | zavyalovo
# Processing Record 28 of Set 6 | battipaglia
# Processing Record 29 of Set 6 | the valley
# Processing Record 30 of Set 6 | lagoa
# Processing Record 31 of Set 6 | le mars
# Processing Record 32 of Set 6 | goundam
# Processing Record 33 of Set 6 | northam
# Processing Record 34 of Set 6 | kuusamo
# Processing Record 35 of Set 6 | piacabucu
# Processing Record 36 of Set 6 | narsaq
# Processing Record 37 of Set 6 | rio grande
# Processing Record 38 of Set 6 | cherskiy
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | kathmandu
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | sabha
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | kandrian
# Processing Record 45 of Set 6 | plettenberg bay
# Processing Record 46 of Set 6 | chapais
# Processing Record 47 of Set 6 | lorengau
# Processing Record 48 of Set 6 | sechura
# Processing Record 49 of Set 6 | kabanjahe
# Processing Record 50 of Set 6 | provost
# Processing Record 1 of Set 7 | puerto escondido
# Processing Record 2 of Set 7 | upata
# Processing Record 3 of Set 7 | laguna
# Processing Record 4 of Set 7 | mehamn
# Processing Record 5 of Set 7 | guerrero negro
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | formosa
# Processing Record 8 of Set 7 | east london
# Processing Record 9 of Set 7 | namatanai
# Processing Record 10 of Set 7 | kupang
# Processing Record 11 of Set 7 | kaitong
# Processing Record 12 of Set 7 | ardakan
# Processing Record 13 of Set 7 | cabra
# Processing Record 14 of Set 7 | fortuna
# Processing Record 15 of Set 7 | saint-malo
# Processing Record 16 of Set 7 | diapaga
# Processing Record 17 of Set 7 | sentyabrskiy
# City 'sentyabrskiy' not found. Skipping...
# Processing Record 18 of Set 7 | sakakah
# Processing Record 19 of Set 7 | lolua
# City 'lolua' not found. Skipping...
# Processing Record 20 of Set 7 | preobrazheniye
# Processing Record 21 of Set 7 | carutapera
# Processing Record 22 of Set 7 | sao joao da barra
# Processing Record 23 of Set 7 | chuy
# Processing Record 24 of Set 7 | rawannawi
# City 'rawannawi' not found. Skipping...
# Processing Record 25 of Set 7 | mwingi
# Processing Record 26 of Set 7 | samusu
# City 'samusu' not found. Skipping...
# Processing Record 27 of Set 7 | teknaf
# Processing Record 28 of Set 7 | nangwa
# Processing Record 29 of Set 7 | thinadhoo
# Processing Record 30 of Set 7 | gold coast
# Processing Record 31 of Set 7 | mount gambier
# Processing Record 32 of Set 7 | amazar
# Processing Record 33 of Set 7 | hualmay
# Processing Record 34 of Set 7 | jamame
# Processing Record 35 of Set 7 | inongo
# Processing Record 36 of Set 7 | oktyabrskiy
# Processing Record 37 of Set 7 | lompoc
# Processing Record 38 of Set 7 | chokurdakh
# Processing Record 39 of Set 7 | attawapiskat
# City 'attawapiskat' not found. Skipping...
# Processing Record 40 of Set 7 | cabedelo
# Processing Record 41 of Set 7 | vardo
# Processing Record 42 of Set 7 | poya
# Processing Record 43 of Set 7 | tautira
# Processing Record 44 of Set 7 | palma di montechiaro
# Processing Record 45 of Set 7 | maloy
# Processing Record 46 of Set 7 | wajid
# Processing Record 47 of Set 7 | gweru
# Processing Record 48 of Set 7 | coos bay
# Processing Record 49 of Set 7 | klyuchi
# Processing Record 50 of Set 7 | andenes
# Processing Record 1 of Set 8 | beyneu
# Processing Record 2 of Set 8 | maunabo
# Processing Record 3 of Set 8 | avera
# Processing Record 4 of Set 8 | baykit
# Processing Record 5 of Set 8 | soe
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | ahipara
# Processing Record 8 of Set 8 | lucapa
# Processing Record 9 of Set 8 | yulara
# Processing Record 10 of Set 8 | owo
# Processing Record 11 of Set 8 | umm kaddadah
# Processing Record 12 of Set 8 | shelburne
# Processing Record 13 of Set 8 | severnoye
# Processing Record 14 of Set 8 | viedma
# Processing Record 15 of Set 8 | elko
# Processing Record 16 of Set 8 | maragogi
# Processing Record 17 of Set 8 | sirpur
# Processing Record 18 of Set 8 | kieta
# Processing Record 19 of Set 8 | menomonie
# Processing Record 20 of Set 8 | santa helena de goias
# Processing Record 21 of Set 8 | matamoros
# Processing Record 22 of Set 8 | burns lake
# Processing Record 23 of Set 8 | oyama
# Processing Record 24 of Set 8 | kitgum
# Processing Record 25 of Set 8 | porto novo
# Processing Record 26 of Set 8 | anahuac
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | udachnyy
# Processing Record 29 of Set 8 | sisimiut
# Processing Record 30 of Set 8 | atambua
# Processing Record 31 of Set 8 | horta
# Processing Record 32 of Set 8 | ola
# Processing Record 33 of Set 8 | muravlenko
# Processing Record 34 of Set 8 | palabuhanratu
# City 'palabuhanratu' not found. Skipping...
# Processing Record 35 of Set 8 | mamallapuram
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | vinh
# Processing Record 38 of Set 8 | puerto baquerizo moreno
# Processing Record 39 of Set 8 | svetlyy
# Processing Record 40 of Set 8 | adrar
# Processing Record 41 of Set 8 | berdigestyakh
# Processing Record 42 of Set 8 | port lincoln
# Processing Record 43 of Set 8 | las choapas
# Processing Record 44 of Set 8 | wajima
# Processing Record 45 of Set 8 | iqaluit
# Processing Record 46 of Set 8 | pandaan
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | yining
# Processing Record 49 of Set 8 | sarangani
# Processing Record 50 of Set 8 | yar-sale
# Processing Record 1 of Set 9 | nguiu
# City 'nguiu' not found. Skipping...
# Processing Record 2 of Set 9 | zhangjiakou
# Processing Record 3 of Set 9 | lavumisa
# Processing Record 4 of Set 9 | tilichiki
# Processing Record 5 of Set 9 | saint-pacome
# City 'saint-pacome' not found. Skipping...
# Processing Record 6 of Set 9 | cullinan
# Processing Record 7 of Set 9 | camana
# Processing Record 8 of Set 9 | arrifes
# Processing Record 9 of Set 9 | troutdale
# Processing Record 10 of Set 9 | abalak
# Processing Record 11 of Set 9 | vao
# Processing Record 12 of Set 9 | atka
# City 'atka' not found. Skipping...
# Processing Record 13 of Set 9 | nigde
# Processing Record 14 of Set 9 | gistrup
# Processing Record 15 of Set 9 | vila franca do campo
# Processing Record 16 of Set 9 | cimarron hills
# Processing Record 17 of Set 9 | ust-karsk
# Processing Record 18 of Set 9 | college
# Processing Record 19 of Set 9 | tazovskiy
# Processing Record 20 of Set 9 | leningradskiy
# Processing Record 21 of Set 9 | markapur
# Processing Record 22 of Set 9 | tezu
# Processing Record 23 of Set 9 | umm lajj
# Processing Record 24 of Set 9 | thunder bay
# Processing Record 25 of Set 9 | touros
# Processing Record 26 of Set 9 | new castle
# Processing Record 27 of Set 9 | jacareacanga
# Processing Record 28 of Set 9 | abay
# Processing Record 29 of Set 9 | blackwater
# Processing Record 30 of Set 9 | manaure
# Processing Record 31 of Set 9 | alice springs
# Processing Record 32 of Set 9 | gazanjyk
# Processing Record 33 of Set 9 | bow island
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | parakou
# Processing Record 36 of Set 9 | tura
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | geresk
# City 'geresk' not found. Skipping...
# Processing Record 39 of Set 9 | mezen
# Processing Record 40 of Set 9 | port hedland
# Processing Record 41 of Set 9 | saint-lo
# Processing Record 42 of Set 9 | acajutla
# Processing Record 43 of Set 9 | la gaulette
# City 'la gaulette' not found. Skipping...
# Processing Record 44 of Set 9 | gallup
# Processing Record 45 of Set 9 | kimberley
# Processing Record 46 of Set 9 | mitu
# Processing Record 47 of Set 9 | marawi
# Processing Record 48 of Set 9 | martil
# Processing Record 49 of Set 9 | dubrovnik
# Processing Record 50 of Set 9 | kanye
# Processing Record 1 of Set 10 | san juan
# Processing Record 2 of Set 10 | grand centre
# City 'grand centre' not found. Skipping...
# Processing Record 3 of Set 10 | inhambane
# Processing Record 4 of Set 10 | miri
# Processing Record 5 of Set 10 | lima
# Processing Record 6 of Set 10 | curup
# Processing Record 7 of Set 10 | wairoa
# Processing Record 8 of Set 10 | borovoy
# Processing Record 9 of Set 10 | amapa
# Processing Record 10 of Set 10 | wanaka
# Processing Record 11 of Set 10 | upernavik
# Processing Record 12 of Set 10 | sungaipenuh
# Processing Record 13 of Set 10 | naron
# Processing Record 14 of Set 10 | sterling
# Processing Record 15 of Set 10 | mount isa
# Processing Record 16 of Set 10 | plavsk
# Processing Record 17 of Set 10 | te anau
# Processing Record 18 of Set 10 | erenhot
# Processing Record 19 of Set 10 | bouna
# Processing Record 20 of Set 10 | acapulco
# Processing Record 21 of Set 10 | jalu
# Processing Record 22 of Set 10 | phan rang
# City 'phan rang' not found. Skipping...
# Processing Record 23 of Set 10 | aberfoyle
# Processing Record 24 of Set 10 | chumikan
# Processing Record 25 of Set 10 | dire
# Processing Record 26 of Set 10 | cua
# Processing Record 27 of Set 10 | meyungs
# City 'meyungs' not found. Skipping...
# Processing Record 28 of Set 10 | half moon bay
# Processing Record 29 of Set 10 | westport
# Processing Record 30 of Set 10 | champerico
# Processing Record 31 of Set 10 | barawe
# City 'barawe' not found. Skipping...
# Processing Record 32 of Set 10 | stranraer
# Processing Record 33 of Set 10 | port-gentil
# Processing Record 34 of Set 10 | valenii de munte
# Processing Record 35 of Set 10 | chinchani
# Processing Record 36 of Set 10 | dawson creek
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | mogochin
# City 'mogochin' not found. Skipping...
# Processing Record 39 of Set 10 | voznesenye
# Processing Record 40 of Set 10 | celestun
# Processing Record 41 of Set 10 | nileshwar
# Processing Record 42 of Set 10 | kiunga
# Processing Record 43 of Set 10 | kenai
# Processing Record 44 of Set 10 | pozo colorado
# Processing Record 45 of Set 10 | warrington
# Processing Record 46 of Set 10 | arman
# Processing Record 47 of Set 10 | kirakira
# Processing Record 48 of Set 10 | alofi
# Processing Record 49 of Set 10 | gubkinskiy
# Processing Record 50 of Set 10 | comodoro rivadavia
# Processing Record 1 of Set 11 | qinggang
# Processing Record 2 of Set 11 | nehe
# Processing Record 3 of Set 11 | tual
# Processing Record 4 of Set 11 | naze
# Processing Record 5 of Set 11 | airai
# Processing Record 6 of Set 11 | shanghai
# Processing Record 7 of Set 11 | oranjemund
# Processing Record 8 of Set 11 | launceston
# Processing Record 9 of Set 11 | palatka
# Processing Record 10 of Set 11 | palu
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | altoona
# Processing Record 13 of Set 11 | hofn
# Processing Record 14 of Set 11 | pierre
# Processing Record 15 of Set 11 | trincomalee
# Processing Record 16 of Set 11 | peniche
# Processing Record 17 of Set 11 | bonavista
# Processing Record 18 of Set 11 | ossora
# Processing Record 19 of Set 11 | paradwip
# City 'paradwip' not found. Skipping...
# Processing Record 20 of Set 11 | santa fe
# Processing Record 21 of Set 11 | aykhal
# Processing Record 22 of Set 11 | marsa matruh
# Processing Record 23 of Set 11 | srednekolymsk
# Processing Record 24 of Set 11 | vitimskiy
# City 'vitimskiy' not found. Skipping...
# Processing Record 25 of Set 11 | inirida
# Processing Record 26 of Set 11 | hit
# Processing Record 27 of Set 11 | san patricio
# Processing Record 28 of Set 11 | puerto leguizamo
# Processing Record 29 of Set 11 | iturama
# Processing Record 30 of Set 11 | ayagoz
# Processing Record 31 of Set 11 | yeppoon
# Processing Record 32 of Set 11 | bosansko grahovo
# Processing Record 33 of Set 11 | chakia
# Processing Record 34 of Set 11 | coquimbo
# Processing Record 35 of Set 11 | fort saint john
# City 'fort saint john' not found. Skipping...
# Processing Record 36 of Set 11 | safaqis
# City 'safaqis' not found. Skipping...
# Processing Record 37 of Set 11 | isla mujeres
# Processing Record 38 of Set 11 | rantauprapat
# Processing Record 39 of Set 11 | parabel
# Processing Record 40 of Set 11 | weihai
# Processing Record 41 of Set 11 | goderich
# Processing Record 42 of Set 11 | honiara
# Processing Record 43 of Set 11 | moussoro
# Processing Record 44 of Set 11 | pontes e lacerda
# Processing Record 45 of Set 11 | mackay
# Processing Record 46 of Set 11 | kugesi
# Processing Record 47 of Set 11 | poronaysk
# Processing Record 48 of Set 11 | eureka
# Processing Record 49 of Set 11 | nogliki
# Processing Record 50 of Set 11 | pisco
# Processing Record 1 of Set 12 | mombetsu
# Processing Record 2 of Set 12 | khatima
# Processing Record 3 of Set 12 | sao gabriel da cachoeira
# Processing Record 4 of Set 12 | san fernando
# Processing Record 5 of Set 12 | walvis bay
# Processing Record 6 of Set 12 | bracebridge
# Processing Record 7 of Set 12 | egvekinot
# Processing Record 8 of Set 12 | hokitika
# Processing Record 9 of Set 12 | kawhia
# Processing Record 10 of Set 12 | mbeya
# Processing Record 11 of Set 12 | cap malheureux
# Processing Record 12 of Set 12 | kozhva
# Processing Record 13 of Set 12 | haines junction
# Processing Record 14 of Set 12 | nueva helvecia
# Processing Record 15 of Set 12 | aland
# Processing Record 16 of Set 12 | salalah
# Processing Record 17 of Set 12 | eirunepe
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | tokur
# Processing Record 20 of Set 12 | marcona
# City 'marcona' not found. Skipping...
# Processing Record 21 of Set 12 | axim
# Processing Record 22 of Set 12 | trinidad
# Processing Record 23 of Set 12 | mareeba
# Processing Record 24 of Set 12 | chiang khong
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | namtsy
# Processing Record 27 of Set 12 | baiyin
# Processing Record 28 of Set 12 | nayoro
# Processing Record 29 of Set 12 | griffith
# Processing Record 30 of Set 12 | bhiwandi
# Processing Record 31 of Set 12 | leh
# Processing Record 32 of Set 12 | presidente medici
# Processing Record 33 of Set 12 | beatrice
# Processing Record 34 of Set 12 | haibowan
# City 'haibowan' not found. Skipping...
# Processing Record 35 of Set 12 | ghanzi
# Processing Record 36 of Set 12 | madison
# Processing Record 37 of Set 12 | asau
# Processing Record 38 of Set 12 | canatlan
# Processing Record 39 of Set 12 | vodyane
# Processing Record 40 of Set 12 | nanyuki
# Processing Record 41 of Set 12 | muyuka
# Processing Record 42 of Set 12 | rantepao
# Processing Record 43 of Set 12 | karaul
# City 'karaul' not found. Skipping...
# Processing Record 44 of Set 12 | annau
# Processing Record 45 of Set 12 | huayang
# Processing Record 46 of Set 12 | bichura
# Processing Record 47 of Set 12 | samarai
# Processing Record 48 of Set 12 | suez
# Processing Record 49 of Set 12 | sambava
# Processing Record 50 of Set 12 | camocim
# Processing Record 1 of Set 13 | greenfield
# Processing Record 2 of Set 13 | fonte boa
# Processing Record 3 of Set 13 | iracoubo
# Processing Record 4 of Set 13 | kimbe
# Processing Record 5 of Set 13 | porto belo
# Processing Record 6 of Set 13 | portland
# Processing Record 7 of Set 13 | big rapids
# Processing Record 8 of Set 13 | armacao dos buzios
# City 'armacao dos buzios' not found. Skipping...
# Processing Record 9 of Set 13 | berezovyy
# Processing Record 10 of Set 13 | bukama
# Processing Record 11 of Set 13 | arawa
# Processing Record 12 of Set 13 | tigil
# Processing Record 13 of Set 13 | gat
# Processing Record 14 of Set 13 | garissa
# Processing Record 15 of Set 13 | maningrida
# Processing Record 16 of Set 13 | la palma del condado
# Processing Record 17 of Set 13 | sept-iles
# Processing Record 18 of Set 13 | belyy yar
# Processing Record 19 of Set 13 | avigliana
# Processing Record 20 of Set 13 | laramie
# Processing Record 21 of Set 13 | lewistown
# Processing Record 22 of Set 13 | isangel
# Processing Record 23 of Set 13 | high level
# Processing Record 24 of Set 13 | grand forks
# Processing Record 25 of Set 13 | midland
# Processing Record 26 of Set 13 | zafra
# Processing Record 27 of Set 13 | vorotynets
# Processing Record 28 of Set 13 | paita
# Processing Record 29 of Set 13 | dhandhuka
# Processing Record 30 of Set 13 | tambovka
# Processing Record 31 of Set 13 | beringovskiy
# Processing Record 32 of Set 13 | kumano
# Processing Record 33 of Set 13 | bolungarvik
# City 'bolungarvik' not found. Skipping...
# Processing Record 34 of Set 13 | abu jubayhah
# City 'abu jubayhah' not found. Skipping...
# Processing Record 35 of Set 13 | barreirinha
# Processing Record 36 of Set 13 | gaya
# Processing Record 37 of Set 13 | itarema
# Processing Record 38 of Set 13 | kangaatsiaq
# Processing Record 39 of Set 13 | mangrol
# Processing Record 40 of Set 13 | yunguyo
# Processing Record 41 of Set 13 | rungata
# City 'rungata' not found. Skipping...
# Processing Record 42 of Set 13 | vestmannaeyjar
# Processing Record 43 of Set 13 | auki
# Processing Record 44 of Set 13 | san carlos
# Processing Record 45 of Set 13 | boldu
# Processing Record 46 of Set 13 | samana
# Processing Record 47 of Set 13 | gigmoto
# Processing Record 48 of Set 13 | sabzevar
# Processing Record 49 of Set 13 | pingshan
# Processing Record 50 of Set 13 | satitoa
# City 'satitoa' not found. Skipping...
# Processing Record 1 of Set 14 | shitanjing
# Processing Record 2 of Set 14 | piney green
# Processing Record 3 of Set 14 | mvuma
# Processing Record 4 of Set 14 | high rock
# Processing Record 5 of Set 14 | anandnagar
# Processing Record 6 of Set 14 | manta
# Processing Record 7 of Set 14 | shimoda
# Processing Record 8 of Set 14 | garoua
# Processing Record 9 of Set 14 | ko samui
# Processing Record 10 of Set 14 | louisbourg
# City 'louisbourg' not found. Skipping...
# Processing Record 11 of Set 14 | chatellerault
# Processing Record 12 of Set 14 | jinotega
# Processing Record 13 of Set 14 | estelle
# Processing Record 14 of Set 14 | oistins
# Processing Record 15 of Set 14 | meulaboh
# Processing Record 16 of Set 14 | bagn
# Processing Record 17 of Set 14 | villarrobledo
# Processing Record 18 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 14 | gotsu
# Processing Record 20 of Set 14 | mattoon
# Processing Record 21 of Set 14 | najran
# Processing Record 22 of Set 14 | sao felix do xingu
# Processing Record 23 of Set 14 | chagoda
# Processing Record 24 of Set 14 | daryapur
# Processing Record 25 of Set 14 | faro
# Processing Record 26 of Set 14 | kamenka
# Processing Record 27 of Set 14 | santa cruz
# Processing Record 28 of Set 14 | hasaki
# Processing Record 29 of Set 14 | west bay
# Processing Record 30 of Set 14 | saint-pierre
# Processing Record 31 of Set 14 | belaya gora
# Processing Record 32 of Set 14 | komsomolskiy
# Processing Record 33 of Set 14 | augustow
# Processing Record 34 of Set 14 | sorong
# Processing Record 35 of Set 14 | shurugwi
# Processing Record 36 of Set 14 | yarada
# Processing Record 37 of Set 14 | oskarshamn
# Processing Record 38 of Set 14 | shetpe
# Processing Record 39 of Set 14 | jinka
# Processing Record 40 of Set 14 | netivot
# Processing Record 41 of Set 14 | vallenar
# Processing Record 42 of Set 14 | bargal
# City 'bargal' not found. Skipping...
# Processing Record 43 of Set 14 | monster
# Processing Record 44 of Set 14 | ewa beach
# Processing Record 45 of Set 14 | yerbogachen
# Processing Record 46 of Set 14 | port augusta
# Processing Record 47 of Set 14 | kununurra
# Processing Record 48 of Set 14 | kyren
# Processing Record 49 of Set 14 | wuwei
# Processing Record 50 of Set 14 | stillwater
# Processing Record 1 of Set 15 | yaan
# Processing Record 2 of Set 15 | marrakesh
# Processing Record 3 of Set 15 | evanton
# Processing Record 4 of Set 15 | kaeo
# Processing Record 5 of Set 15 | porto walter
# Processing Record 6 of Set 15 | sao jose da coroa grande
# Processing Record 7 of Set 15 | hami
# Processing Record 8 of Set 15 | guayaramerin
# Processing Record 9 of Set 15 | huntington
# Processing Record 10 of Set 15 | kotturu
# Processing Record 11 of Set 15 | oksfjord
# Processing Record 12 of Set 15 | lalomanu
# City 'lalomanu' not found. Skipping...
# Processing Record 13 of Set 15 | leczna
# Processing Record 14 of Set 15 | ajdabiya
# Processing Record 15 of Set 15 | huambo
# Processing Record 16 of Set 15 | hamilton
# Processing Record 17 of Set 15 | navalmoral de la mata
# Processing Record 18 of Set 15 | rio gallegos
# Processing Record 19 of Set 15 | lalibela
# Processing Record 20 of Set 15 | evensk
# Processing Record 21 of Set 15 | umzimvubu
# City 'umzimvubu' not found. Skipping...
# Processing Record 22 of Set 15 | pemangkat
# Processing Record 23 of Set 15 | shalakusha
# Processing Record 24 of Set 15 | viligili
# City 'viligili' not found. Skipping...
# Processing Record 25 of Set 15 | padampur
# Processing Record 26 of Set 15 | antofagasta
# Processing Record 27 of Set 15 | bukachacha
# Processing Record 28 of Set 15 | vrangel
# Processing Record 29 of Set 15 | brigantine
# Processing Record 30 of Set 15 | wynyard
# Processing Record 31 of Set 15 | severo-yeniseyskiy
# Processing Record 32 of Set 15 | el alto
# Processing Record 33 of Set 15 | dingle
# Processing Record 34 of Set 15 | beloha
# Processing Record 35 of Set 15 | zyryanka
# Processing Record 36 of Set 15 | abha
# Processing Record 37 of Set 15 | enkhuizen
# Processing Record 38 of Set 15 | urumqi
# Processing Record 39 of Set 15 | palana
# Processing Record 40 of Set 15 | parkes
# Processing Record 41 of Set 15 | tena
# Processing Record 42 of Set 15 | falun
# Processing Record 43 of Set 15 | lokosovo
# Processing Record 44 of Set 15 | korem
# Processing Record 45 of Set 15 | zatoka
# Processing Record 46 of Set 15 | odweyne
# Processing Record 47 of Set 15 | nokaneng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Punta Arenas -53.15  -70.92     37.40        86         100        8.05
# 1         Avarua -21.21 -159.78     78.80        83           2        8.05
# 2          Dedza -14.38   34.33     46.60        96          55        5.01
# 3      Mahebourg -20.41   57.70     66.20        88          40       11.41
# 4          Pafos  34.77   32.42     73.40        73           0        5.82
# 5  Novyy Urengoy  66.08   76.63     46.60        65           0       21.97
# 6        Ushuaia -54.80  -68.30     37.40        88          75        4.68
# 7       Olafsvik  64.89  -23.71     45.48        73         100        2.44
# 8      Beisfjord  68.38   17.60     53.60        87         100       16.11
# 9       Cidreira -30.18  -50.21     55.96        85           0       10.02
#
#   Country Current Description
# 0      CL     overcast clouds
# 1      CK          light rain
# 2      MW       broken clouds
# 3      MU         shower rain
# 4      CY           clear sky
# 5      RU           clear sky
# 6      AR       broken clouds
# 7      IS     overcast clouds
# 8      NO          light rain
# 9      BR           clear sky

# %%
# Rearrange the column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.15  -70.92     37.40        86         100
# 1          Avarua      CK -21.21 -159.78     78.80        83           2
# 2           Dedza      MW -14.38   34.33     46.60        96          55
# 3       Mahebourg      MU -20.41   57.70     66.20        88          40
# 4           Pafos      CY  34.77   32.42     73.40        73           0
# ..            ...     ...    ...     ...       ...       ...         ...
# 684      Lokosovo      RU  61.13   74.82     46.87        68          92
# 685         Korem      ET  12.51   39.52     57.31        81          15
# 686        Zatoka      UA  46.07   30.47     64.40       100          75
# 687       Odweyne      SO   9.41   45.06     74.41        49          22
# 688      Nokaneng      BW -19.67   22.27     65.30        40           0
#
#      Wind Speed Current Description
# 0          8.05     overcast clouds
# 1          8.05          light rain
# 2          5.01       broken clouds
# 3         11.41         shower rain
# 4          5.82           clear sky
# ..          ...                 ...
# 684       13.91     overcast clouds
# 685        1.61          few clouds
# 686       22.37       broken clouds
# 687       17.85          few clouds
# 688       10.74           clear sky
#
# [689 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
